# %% [markdown]
# # numpy

# %% [markdown]
# ## Задача №1. Скользящее окно
#
# Реализовать функцию скользящего окна для заданного одномерного ряда данных, формирующую из него матрицу по следующему правилу:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Аргументы функции:
#
# *x_array* - одномерный массив **numpy.ndarray**
#
# *w* - ширина окна для итоговой матрицы
#
# *step* - шаг окна по исходному одномерному ряду данных
#
# Результат:
#
# *A_matrix* - матрица скользящего среднего

# %%
import numpy as np

# %%
def sliding_window(x_array, w, step = 1):
    A_matrix = []
    for i in range(0, len(x_array), step):
        if len(x_array[i:(i + w)]) < w:
            return A_matrix
        A_matrix.append(x_array[i:(i + w)])
    return A_matrix

# %%
# проверка 1
window = 3
step_s = 1
x1 = np.array([8, 1, 4, 5, -2, 5, 9, 0])
A1 = np.array([[8, 1, 4],
               [1, 4, 5],
               [4, 5, -2],
               [5, -2, 5],
               [-2, 5, 9],
               [5, 9, 0]])

print(np.array_equal(sliding_window(x1, w=window, step=step_s),A1))

# проверка 2
window = 2
step_s = 4
x2 = np.array([8, 3, 4, 1, -6, 5, 9, 2, 10, 11, -14, 0])
A2 = np.array([[8, 3],
               [-6, 5],
               [10, 11]])

print(np.array_equal(sliding_window(x2, w=window, step=step_s),A2))
# Out:
# True
# True

# %% [markdown]
# # **Анализ данных по доходу населения UCI Adult**
#
#
# Автор материала: Юрий Кашницкий (@yorko в Slack ODS). Материал распространяется на условиях лицензии Creative Commons CC BY-NC-SA 4.0. Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# **В задании предлагается с помощью Pandas ответить на несколько вопросов по данным репозитория UCI [Adult](https://archive.ics.uci.edu/ml/datasets/Adult)**
#
# Уникальные значения признаков (больше информации по ссылке выше):
#
# - age: continuous.
#
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - salary: >50K,<=50K

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", sep = ", ", header=None,
                   names = ["age", "workclass", "fnlwgt", "education",
                    "education-num", "marital-status", "occupation", "relationship",
                    "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "salary"])

list_of_objects = data.dtypes.axes[0][data.dtypes == "object"]
data[list_of_objects] = data[list_of_objects].astype("string")

data.head()
# Out:
# <ipython-input-1-a514d36f58ff>:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", sep = ", ", header=None,
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ## **0. Изучить в документации методы groupby и agg**

# %% [markdown]
# ## **1. Сколько мужчин и женщин (признак sex) представлено в этом наборе данных?**
#
# ### Визуализировать результат

# %%
# @title Количество людей
data.groupby(['sex']).agg({'age': ['count']}).rename(columns = {'age':'number_of_person', 'count':''})
# Out:
#        number_of_person
#
# sex
# Female            10771
# Male              21790

# %% [markdown]
# ## **2. Каков средний возраст (признак age) женщин?**

# %%
data[data['sex'] == 'Female']['age'].mean()
# Out:
# 36.85823043357163

# %% [markdown]
# ## **3. Какова доля граждан Германии (признак native-country)?**

# %%
round(data[data['native-country'] == 'Germany']['age'].count() / data['native-country'].count(), 4) * 100
# Out:
# 0.42

# %% [markdown]
# ## **4-5. Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак salary) и тех, кто получает менее 50K в год?**
#
# ### Визуализировать результат

# %%
# @title Возраст при доходе
mean_age_high = round(data.loc[data['salary'] == '>50K']['age'].mean())
mean_age_low = round(data.loc[data['salary'] == '<=50K']['age'].mean())
std_age_high = round(data.loc[data['salary'] == '>50K']['age'].std())
std_age_low = round(data.loc[data['salary'] == '<=50K']['age'].std())
d = {'Доход': ['Высокий', 'Низкий'],
     'Средний возраст': [mean_age_high, mean_age_low],
     'Стандартное отклонение возраста': [std_age_high, std_age_low]}
ans = pd.DataFrame(d).set_index('Доход')
ans
# Out:
#          Средний возраст  Стандартное отклонение возраста
# Доход
# Высокий               44                               11
# Низкий                37                               14

# %% [markdown]
# ## **6. Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)**

# %%
edu = ('Bachelors', 'Prof-school', 'Assoc-acdm', 'Assoc-voc', 'Masters', 'Doctorate')
tmp = data[data['salary'] == '>50K']['education'].value_counts().reset_index()
sum_high = 0
sum = tmp['education'].sum()
for i in range(len(tmp)):
    if tmp.iloc[i][0] in edu:
        sum_high += tmp.iloc[i][1]
print(f'{sum_high} людей с высшим образованием получают больше 50к')
print(f'{sum} людей получают больше 50к')
print(f'{round(sum_high/sum, 2)} - доля людей с высшим среди всех, кото зарабатывает больше 50к => образование не влияет на доход')
# Out:
# 4535 людей с высшим образованием получают больше 50к
# 7841 людей получают больше 50к
# 0.58 - доля людей с высшим среди всех, кото зарабатывает больше 50к => образование не влияет на доход

# %% [markdown]
# ## **7. Выведите статистику возраста для каждой расы (признак race) и каждого пола. Используйте groupby и describe. Найдите таким образом максимальный возраст мужчин расы Amer-Indian-Eskimo.**

# %%
tmp_df = data.groupby(['race', 'sex']).describe()
print('Максимальный возраст мужчин расы Amer-Indian-Eskimo =', round(tmp_df.loc['Amer-Indian-Eskimo', 'Male']['age']['max']))
tmp_df
# Out:
# Максимальный возраст мужчин расы Amer-Indian-Eskimo = 82
#                                age                                          \
#                              count       mean        std   min   25%   50%
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
# ...

# %% [markdown]
# ## **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status)? Женатыми считаем тех, у кого marital-status начинается с Married (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**
#
# ### Визуализировать результат

# %%
marrie = ('Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse')
tmp_high = data[(data['salary'] == '>50K') & (data['sex'] == 'Male')]['marital-status'].value_counts().reset_index()
sum_high_mer = 0
sum_high_nomer = 0
sum_all = 0
''
for i in range(len(tmp_high)):
    if tmp_high.iloc[i][0] in marrie:
        sum_high_mer += tmp_high.iloc[i][1]
    else:
        sum_high_nomer += tmp_high.iloc[i][1]
    sum_all += tmp_high.iloc[i][1]
part_mer = sum_high_mer / sum_all
part_nomer = sum_high_nomer / sum_all
part_mer = round(part_mer * 100)
part_nomer = round(part_nomer * 100)

datas = [part_mer, part_nomer]
fig = plt.figure(figsize =(5, 5))
plt.pie(datas, colors=('#5A50E2', '#FCCD00'))
plt.annotate(f'Женатые, {datas[0]}%',
             (-0.3, 0.8),
             c='white')
plt.annotate(f'Неженатые, \n{datas[1]}%',
             (0.3, -0.2),
             )
plt.show()

# %% [markdown]
# ## **9. Какое максимальное число часов человек работает в неделю (признак hours-per-week)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
mx = data['hours-per-week'].max()
count_mx = data[data['hours-per-week'] == mx]['age'].count()
part = data[(data['hours-per-week'] == mx) & (data['salary'] == '>50K')]['age'].count() / count_mx * 100
print(f'Макс число часов = {mx}ч.\nКол-во людей работающих {mx}ч. = {count_mx}\nПроцент зарабатывающих много людей, которые работают {99}ч. = {round(part, 2)}%')
# Out:
# Макс число часов = 99ч.
# Кол-во людей работающих 99ч. = 85
# Процент зарабатывающих много людей, которые работают 99ч. = 29.41%

# %% [markdown]
# ## **10. Посчитайте среднее время работы (hours-per-week) зарабатывающих мало и много (salary) для каждой страны (native-country).**
#
# ### Визуализировать результат

# %%
# @title Среднее время работы по убивынию
tmp = data.groupby(['native-country', 'salary']).agg({'hours-per-week': ['mean']}).reset_index()
tmp_low = tmp[tmp['salary'] == '<=50K'].sort_values(by=[('hours-per-week', 'mean')], ascending=False)
tmp_high = tmp[tmp['salary'] == '>50K'].sort_values(by=[('hours-per-week', 'mean')], ascending=False)
countries = set(tmp['native-country'])

fig, ax = plt.subplots(2, 1)
fig.set_figheight(8)
fig.set_figwidth(20)
ax[0].bar(tmp_low['native-country'][:10], tmp_low['hours-per-week']['mean'][:10], color='#5A50E2', width=0.5)
ax[0].set_title('Среднее кол-во часов при низком доходе', loc = 'left')

ax[1].bar(tmp_low['native-country'][:10], tmp_high['hours-per-week']['mean'][:10], color='#5A50E2', width=0.5)
ax[1].set_title('Среднее кол-во часов при высоком доходе', loc = 'left')
plt.show()
